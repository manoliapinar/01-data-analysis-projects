# %% [markdown]
# <a href="https://colab.research.google.com/github/manoliapinar/data-analysis-projects/blob/main/04_Datavizualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from IPython.display import display

drive.mount('/content/drive')

weather_data = pd.read_csv('/content/drive/My Drive/project-data-analysis/dataset/weather_meteo_by_airport.csv')
cancelled_data = pd.read_csv('/content/drive/My Drive/project-data-analysis/dataset/cancelled_diverted_2023.csv')

print("Données météo :")
display(weather_data.head())

print("\nDonnées vols annulés et détournés :")
display(cancelled_data.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Données météo :
#          time  tavg  tmin  tmax  prcp  snow   wdir  wspd    pres airport_id
# 0  2023-01-01   8.1   2.2  11.7   0.0   0.0  278.0   9.7  1013.8        ABE
# 1  2023-01-02   5.4   0.0  11.7   0.0   0.0  353.0   3.6  1019.6        ABE
# 2  2023-01-03   8.4   7.2   9.4  15.2   0.0   50.0   5.0  1013.9        ABE
# 3  2023-01-04  11.1   6.7  17.2   0.0   0.0  302.0   4.7  1009.8        ABE
# 4  2023-01-05  12.7   6.7  14.4   7.9   0.0  292.0   7.2  1013.0        ABE
# Données vols annulés et détournés :
#    FlightDate  Day_Of_Week       Airline Tail_Number  Cancelled  Diverted  \
# 0  2023-01-25            3  Endeavor Air      N691CA        1.0       0.0
# 1  2023-01-03            2  Endeavor Air      N937XJ        1.0       0.0
# 2  2023-01-03            2  Endeavor Air      N937XJ        1.0       0.0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(weather_data['tavg'], bins=30, kde=True, color='skyblue')
plt.title('Températures')
plt.xlabel('Température (°C)')
plt.ylabel('Fréquence')
plt.grid(True)
plt.show()

# %%
# Filtrer les données pour garder uniquement les vols annulés
cancelled_flights = cancelled_data[cancelled_data['Cancelled'] == 1]

# Diagramme à barres des vols annulés par compagnie aérienne
plt.figure(figsize=(10, 6))
sns.countplot(y='Airline', data=cancelled_flights, palette='viridis')
plt.title('Nombre de vols annulés par compagnie')
plt.xlabel('Nombre de vols annulés')
plt.ylabel('Compagnie')
plt.grid(axis='x')
plt.show()
# Out:
# <ipython-input-34-c3309aacac82>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Airline', data=cancelled_flights, palette='viridis')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Histogramme des retards de départ
plt.figure(figsize=(10, 6))
sns.histplot(cancelled_data['Dep_Delay'], bins=30, kde=True, color='skyblue')
plt.title('Distribution des retards des départs')
plt.xlabel('Retard de départ (en minutes)')
plt.ylabel('Fréquence')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion
#
# Dans cette analyse, j'ai exploré les données relatives aux vols annulés et détournés, ainsi qu'aux conditions météorologiques associées.
#
# 1. **Températures** : Les températures moyennes, minimales et maximales ont été visualisées pour mieux comprendre les conditions climatiques pendant les périodes d'observation.
#
# 2. **Vols annulés par compagnie** : Le diagramme à barres illustrant le nombre de vols annulés par compagnie aérienne a révélé quelles compagnies étaient le plus affectées par les annulations. Cette information peut aider les gestionnaires de compagnies aériennes à prendre des décisions éclairées pour améliorer la fiabilité de leurs services.
#
# 3. **Distribution des retards de départ** : L'histogramme des retards de départ a montré la répartition des retards, ce qui nous permet de comprendre les tendances générales dans les retards des vols. Cela peut être utile pour identifier des périodes particulièrement problématiques.
#
# ### Perspectives Futures
#
# Pour des analyses futures, il serait intéressant d'explorer les relations entre les retards de vol et d'autres facteurs tels que la météo et les heures de pointe des voyageurs. L'intégration de données supplémentaires, comme les informations sur les passagers ou le statut des vols en temps réel, pourrait enrichir l'analyse et fournir des insights encore plus approfondis.
